# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, SubsetRandomSampler
from torchvision import datasets, transforms
import time
import torch.optim as optim
from torch.optim import lr_scheduler

# %%
BATCH_SIZE = 64
NUM_EPOCHS = 20
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])
train_dataset = datasets.MNIST(root='./data',
                                train=True,
                                download=True,
                                transform=transform)
valid_dataset = datasets.MNIST(root='./data',
                                train=True,
                                transform=transform)
test_dataset = datasets.MNIST(root='./data',
                                train=False,
                                transform=transform)
validation_fraction = 0.1
num = int(validation_fraction * 60000)
train_indices = torch.arange(0, 60000 - num)
valid_indices = torch.arange(60000 - num, 60000)
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(valid_indices)

# %%
train_loader = DataLoader(dataset=train_dataset,
                            batch_size=BATCH_SIZE,
                            drop_last=True,
                            sampler=train_sampler)
valid_loader = DataLoader(dataset=valid_dataset,
                            batch_size=BATCH_SIZE,
                            sampler=valid_sampler)
test_loader = DataLoader(dataset=test_dataset,
                            batch_size=BATCH_SIZE,
                            shuffle=False)

# %%
# Checking the dataset
for images, labels in train_loader:
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
# Out:
# Image batch dimensions: torch.Size([64, 1, 28, 28])
# Image label dimensions: torch.Size([64])

# %%
import matplotlib.pyplot as plt
# Display a grid of sample images
plt.figure(figsize=(10, 10))
for i, (images, labels) in enumerate(train_loader):
    for j in range(25):
        plt.subplot(5, 5, j + 1)
        plt.imshow(images[j].squeeze(), cmap='gray')
        plt.axis('off')
    break
plt.show()

# %%
class MLP(nn.Module):
    def __init__(self, num_features, num_hidden_1, num_hidden_2, num_classes):
        super().__init__()
        self.network = torch.nn.Sequential(
            # 1st hidden layer
            torch.nn.Flatten(),
            torch.nn.Linear(num_features, num_hidden_1),
            torch.nn.BatchNorm1d(num_hidden_1),
            torch.nn.ReLU(),
            torch.nn.Dropout(0.5),
            # 2nd hidden layer
            torch.nn.Linear(num_hidden_1, num_hidden_2),
            torch.nn.BatchNorm1d(num_hidden_2),
            torch.nn.ReLU(),
            torch.nn.Dropout(0.3),
            # output layer
            torch.nn.Linear(num_hidden_2, num_classes)
        )
    def forward(self, x):
        logits = self.network(x)
        return logits

# %%
model = MLP(num_features=28*28,
            num_hidden_1=128,
            num_hidden_2=64,
            num_classes=10)
model = model.to(DEVICE)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9,
weight_decay=0.0001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                        factor=0.1,
                                                        mode='min')

# %%
# Define your optimizer (using Adam)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Create the scheduler with step decay
scheduler = lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)

# Create the scheduler with exponential decay
scheduler = lr_scheduler.ExponentialLR(optimizer, gamma=0.95)

# %%
def compute_accuracy(data_loader):
    with torch.no_grad():
        correct_pred, num_examples = 0, 0
        for i, (features, targets) in enumerate(data_loader):
            features = features.to(DEVICE)
            targets = targets.float().to(DEVICE)
            logits = model(features)
            _, predicted_labels = torch.max(logits, 1)
            num_examples += targets.size(0)
            correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100

# %%
start_time = time.time()
minibatch_loss_list, train_acc_list, valid_acc_list = [], [], []
for epoch in range(NUM_EPOCHS):
    
    model.train()
    
    for batch_idx, (features, targets) in enumerate(train_loader):
        
        features = features.to(DEVICE)
        targets = targets.to(DEVICE)
# ## FORWARD AND BACK PROP
        logits = model(features)
#loss = F.cross_entropy(logits, targets)
        loss = criterion(logits, targets)
        optimizer.zero_grad()
        loss.backward()
# ## UPDATE MODEL PARAMETERS
        optimizer.step()
# ## LOGGING
        minibatch_loss_list.append(loss.item())
        logging_interval = 100
        if not batch_idx % logging_interval:
            print("Epoch: ", epoch+1,"/", NUM_EPOCHS,"| Batch ",batch_idx,
            "/",len(train_loader), f'| Loss: {loss:.4f}')
            model.eval()
            with torch.no_grad():# save memory during inference
                
                train_acc = compute_accuracy(train_loader)
                valid_acc = compute_accuracy(valid_loader)
                print("Epoch: ", epoch+1, "/",NUM_EPOCHS,
                f'| Train: {train_acc :.2f}% '
                f'| Validation: {valid_acc :.2f}%')
                train_acc_list.append(train_acc.item())
                valid_acc_list.append(valid_acc.item())
                elapsed = (time.time() - start_time)/60
                print("Time elapsed: ",elapsed, " min")
                scheduler.step(minibatch_loss_list[-1])
                elapsed = (time.time() - start_time)/60
                print(f'Total Training Time: {elapsed:.2f} min')
                test_acc = compute_accuracy(test_loader)
                print(f'Test accuracy {test_acc :.2f}%')
# Out:
# Epoch:  1 / 20 | Batch  0 / 843 | Loss: 2.4980
# Epoch:  1 / 20 | Train: 9.23% | Validation: 9.28%
# Time elapsed:  0.029177955786387124  min
# Total Training Time: 0.03 min
# /opt/anaconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:156: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Test accuracy 8.13%
# Epoch:  1 / 20 | Batch  100 / 843 | Loss: 0.4375
# Epoch:  1 / 20 | Train: 84.66% | Validation: 88.15%
# Time elapsed:  0.064536452293396  min
# Total Training Time: 0.06 min
# Test accuracy 85.86%
# Epoch:  1 / 20 | Batch  200 / 843 | Loss: 0.2172
# Epoch:  1 / 20 | Train: 86.47% | Validation: 88.68%
# Time elapsed:  0.10129133462905884  min
# Total Training Time: 0.10 min
# Test accuracy 87.45%
# Epoch:  1 / 20 | Batch  300 / 843 | Loss: 0.3812
# Epoch:  1 / 20 | Train: 89.31% | Validation: 90.80%
# Time elapsed:  0.13715341885884602  min
# Total Training Time: 0.14 min
# Test accuracy 89.72%
# Epoch:  1 / 20 | Batch  400 / 843 | Loss: 0.3613
# Epoch:  1 / 20 | Train: 89.68% | Validation: 91.35%
# Time elapsed:  0.1722186009089152  min
# Total Training Time: 0.17 min
# Test accuracy 90.17%
# Epoch:  1 / 20 | Batch  500 / 843 | Loss: 0.6102
# Epoch:  1 / 20 | Train: 90.64% | Validation: 92.33%
# Time elapsed:  0.20791403452555338  min
# Total Training Time: 0.21 min
# Test accuracy 90.93%
# Epoch:  1 / 20 | Batch  600 / 843 | Loss: 0.4045
# Epoch:  1 / 20 | Train: 91.60% | Validation: 93.30%
# Time elapsed:  0.24281608661015827  min
# Total Training Time: 0.24 min
# Test accuracy 91.99%
# Epoch:  1 / 20 | Batch  700 / 843 | Loss: 0.2995
# Epoch:  1 / 20 | Train: 90.34% | Validation: 92.27%
# Time elapsed:  0.27825295527776084  min
# Total Training Time: 0.28 min
# Test accuracy 91.07%
# Epoch:  1 / 20 | Batch  800 / 843 | Loss: 0.2527
# Epoch:  1 / 20 | Train: 92.66% | Validation: 93.93%
# Time elapsed:  0.3130782683690389  min
# Total Training Time: 0.31 min
# Test accuracy 92.71%
# Epoch:  2 / 20 | Batch  0 / 843 | Loss: 1.2351
# Epoch:  2 / 20 | Train: 92.58% | Validation: 94.02%
# Time elapsed:  0.3472553332646688  min
# Total Training Time: 0.35 min
# Test accuracy 92.81%
# Epoch:  2 / 20 | Batch  100 / 843 | Loss: 0.1180
# Epoch:  2 / 20 | Train: 93.67% | Validation: 95.23%
# Time elapsed:  0.3830357035001119  min
# Total Training Time: 0.38 min
# Test accuracy 93.89%
# Epoch:  2 / 20 | Batch  200 / 843 | Loss: 0.2363
# Epoch:  2 / 20 | Train: 94.07% | Validation: 95.27%
# Time elapsed:  0.4183146357536316  min
# Total Training Time: 0.42 min
# Test accuracy 94.16%
# Epoch:  2 / 20 | Batch  300 / 843 | Loss: 0.1119
# Epoch:  2 / 20 | Train: 94.83% | Validation: 96.07%
# Time elapsed:  0.45373783508936566  min
# Total Training Time: 0.45 min
# Test accuracy 94.71%
# Epoch:  2 / 20 | Batch  400 / 843 | Loss: 0.1577
# Epoch:  2 / 20 | Train: 94.64% | Validation: 95.78%
# Time elapsed:  0.4889565189679464  min
# Total Training Time: 0.49 min
# Test accuracy 94.66%
# Epoch:  2 / 20 | Batch  500 / 843 | Loss: 0.3311
# Epoch:  2 / 20 | Train: 95.03% | Validation: 95.83%
# Time elapsed:  0.5236010352770487  min
# Total Training Time: 0.52 min
# Test accuracy 94.77%
# Epoch:  2 / 20 | Batch  600 / 843 | Loss: 0.1556
# Epoch:  2 / 20 | Train: 95.13% | Validation: 95.98%
# Time elapsed:  0.5594881375630697  min
# Total Training Time: 0.56 min
# Test accuracy 95.30%
# Epoch:  2 / 20 | Batch  700 / 843 | Loss: 0.1011
# Epoch:  2 / 20 | Train: 95.34% | Validation: 96.02%
# Time elapsed:  0.5941011190414429  min
# Total Training Time: 0.59 min
# Test accuracy 95.37%
# Epoch:  2 / 20 | Batch  800 / 843 | Loss: 0.2569
# Epoch:  2 / 20 | Train: 94.78% | Validation: 95.48%
# Time elapsed:  0.6304470340410868  min
# Total Training Time: 0.63 min
# Test accuracy 94.74%
# Epoch:  3 / 20 | Batch  0 / 843 | Loss: 1.2783
# Epoch:  3 / 20 | Train: 95.56% | Validation: 96.17%
# Time elapsed:  0.6646435181299846  min
# Total Training Time: 0.66 min
# Test accuracy 95.42%
# Epoch:  3 / 20 | Batch  100 / 843 | Loss: 0.1470
# Epoch:  3 / 20 | Train: 96.10% | Validation: 96.97%
# Time elapsed:  0.7006674329439799  min
# Total Training Time: 0.70 min
# Test accuracy 95.79%
# Epoch:  3 / 20 | Batch  200 / 843 | Loss: 0.1170
# Epoch:  3 / 20 | Train: 95.63% | Validation: 96.37%
# Time elapsed:  0.7348173538843791  min
# Total Training Time: 0.73 min
# Test accuracy 95.67%
# Epoch:  3 / 20 | Batch  300 / 843 | Loss: 0.1594
# Epoch:  3 / 20 | Train: 96.09% | Validation: 96.57%
# Time elapsed:  0.7702956517537435  min
# Total Training Time: 0.77 min
# Test accuracy 95.89%
# Epoch:  3 / 20 | Batch  400 / 843 | Loss: 0.1848
# Epoch:  3 / 20 | Train: 96.44% | Validation: 97.08%
# Time elapsed:  0.8053491353988648  min
# Total Training Time: 0.81 min
# Test accuracy 96.13%
# Epoch:  3 / 20 | Batch  500 / 843 | Loss: 0.3050
# Epoch:  3 / 20 | Train: 96.22% | Validation: 96.85%
# Time elapsed:  0.8405203501383464  min
# Total Training Time: 0.84 min
# Test accuracy 95.87%
# Epoch:  3 / 20 | Batch  600 / 843 | Loss: 0.1842
# Epoch:  3 / 20 | Train: 96.22% | Validation: 96.80%
# Time elapsed:  0.8752304514249166  min
# Total Training Time: 0.88 min
# Test accuracy 95.75%
# Epoch:  3 / 20 | Batch  700 / 843 | Loss: 0.0642
# Epoch:  3 / 20 | Train: 95.94% | Validation: 96.57%
# Time elapsed:  0.9111865838368733  min
# Total Training Time: 0.91 min
# Test accuracy 95.87%
# Epoch:  3 / 20 | Batch  800 / 843 | Loss: 0.1406
# Epoch:  3 / 20 | Train: 96.88% | Validation: 97.33%
# Time elapsed:  0.9460376699765524  min
# Total Training Time: 0.95 min
# Test accuracy 96.38%
# Epoch:  4 / 20 | Batch  0 / 843 | Loss: 1.1615
# Epoch:  4 / 20 | Train: 96.59% | Validation: 97.08%
# Time elapsed:  0.9807420492172241  min
# Total Training Time: 0.98 min
# Test accuracy 96.17%
# Epoch:  4 / 20 | Batch  100 / 843 | Loss: 0.2135
# Epoch:  4 / 20 | Train: 96.34% | Validation: 96.68%
# Time elapsed:  1.0156244357426962  min
# Total Training Time: 1.02 min
# Test accuracy 96.10%
# Epoch:  4 / 20 | Batch  200 / 843 | Loss: 0.0794
# Epoch:  4 / 20 | Train: 96.63% | Validation: 96.80%
# Time elapsed:  1.0514859000841776  min
# Total Training Time: 1.05 min
# Test accuracy 96.09%
# Epoch:  4 / 20 | Batch  300 / 843 | Loss: 0.1133
# Epoch:  4 / 20 | Train: 96.99% | Validation: 97.13%
# Time elapsed:  1.0866463343302408  min
# Total Training Time: 1.09 min
# Test accuracy 96.58%
# Epoch:  4 / 20 | Batch  400 / 843 | Loss: 0.1120
# Epoch:  4 / 20 | Train: 97.16% | Validation: 97.33%
# Time elapsed:  1.1223624348640442  min
# Total Training Time: 1.12 min
# Test accuracy 96.44%
# Epoch:  4 / 20 | Batch  500 / 843 | Loss: 0.0879
# Epoch:  4 / 20 | Train: 96.78% | Validation: 97.02%
# Time elapsed:  1.1577687025070191  min
# Total Training Time: 1.16 min
# Test accuracy 96.13%
# Epoch:  4 / 20 | Batch  600 / 843 | Loss: 0.0827
# Epoch:  4 / 20 | Train: 96.57% | Validation: 96.82%
# Time elapsed:  1.193480869134267  min
# Total Training Time: 1.19 min
# Test accuracy 96.19%
# Epoch:  4 / 20 | Batch  700 / 843 | Loss: 0.1451
# Epoch:  4 / 20 | Train: 96.99% | Validation: 96.92%
# Time elapsed:  1.2280883034070333  min
# Total Training Time: 1.23 min
# Test accuracy 96.58%
# Epoch:  4 / 20 | Batch  800 / 843 | Loss: 0.2185
# Epoch:  4 / 20 | Train: 96.66% | Validation: 97.12%
# Time elapsed:  1.2640678524971007  min
# Total Training Time: 1.26 min
# Test accuracy 96.24%
# Epoch:  5 / 20 | Batch  0 / 843 | Loss: 0.9540
# Epoch:  5 / 20 | Train: 96.87% | Validation: 97.15%
# Time elapsed:  1.297753918170929  min
# Total Training Time: 1.30 min
# Test accuracy 96.52%
# Epoch:  5 / 20 | Batch  100 / 843 | Loss: 0.0667
# Epoch:  5 / 20 | Train: 97.33% | Validation: 97.37%
# Time elapsed:  1.3321112513542175  min
# Total Training Time: 1.33 min
# Test accuracy 96.73%
# Epoch:  5 / 20 | Batch  200 / 843 | Loss: 0.0646
# Epoch:  5 / 20 | Train: 97.51% | Validation: 97.42%
# Time elapsed:  1.367962916692098  min
# Total Training Time: 1.37 min
# Test accuracy 96.77%
# Epoch:  5 / 20 | Batch  300 / 843 | Loss: 0.0393
# Epoch:  5 / 20 | Train: 97.38% | Validation: 97.35%
# Time elapsed:  1.402482517560323  min
# Total Training Time: 1.40 min
# Test accuracy 96.75%
# Epoch:  5 / 20 | Batch  400 / 843 | Loss: 0.0484
# Epoch:  5 / 20 | Train: 97.30% | Validation: 97.18%
# Time elapsed:  1.4380950371424357  min
# Total Training Time: 1.44 min
# Test accuracy 96.70%
# Epoch:  5 / 20 | Batch  500 / 843 | Loss: 0.0958
# Epoch:  5 / 20 | Train: 97.41% | Validation: 97.33%
# Time elapsed:  1.4723480542500813  min
# Total Training Time: 1.47 min
# Test accuracy 96.52%
# Epoch:  5 / 20 | Batch  600 / 843 | Loss: 0.0657
# Epoch:  5 / 20 | Train: 97.19% | Validation: 96.93%
# Time elapsed:  1.5080079515775044  min
# Total Training Time: 1.51 min
# Test accuracy 96.50%
# Epoch:  5 / 20 | Batch  700 / 843 | Loss: 0.0374
# Epoch:  5 / 20 | Train: 97.59% | Validation: 97.28%
# Time elapsed:  1.542427702744802  min
# Total Training Time: 1.54 min
# Test accuracy 96.75%
# Epoch:  5 / 20 | Batch  800 / 843 | Loss: 0.0866
# Epoch:  5 / 20 | Train: 97.18% | Validation: 97.13%
# Time elapsed:  1.5773797829945881  min
# Total Training Time: 1.58 min
# Test accuracy 96.64%
# Epoch:  6 / 20 | Batch  0 / 843 | Loss: 0.9788
# Epoch:  6 / 20 | Train: 96.94% | Validation: 96.88%
# Time elapsed:  1.6110708514849346  min
# Total Training Time: 1.61 min
# Test accuracy 96.14%
# Epoch:  6 / 20 | Batch  100 / 843 | Loss: 0.0327
# Epoch:  6 / 20 | Train: 97.54% | Validation: 97.43%
# Time elapsed:  1.6468637188275654  min
# Total Training Time: 1.65 min
# Test accuracy 96.77%
# Epoch:  6 / 20 | Batch  200 / 843 | Loss: 0.0251
# Epoch:  6 / 20 | Train: 97.73% | Validation: 97.48%
# Time elapsed:  1.682534921169281  min
# Total Training Time: 1.68 min
# Test accuracy 96.92%
# Epoch:  6 / 20 | Batch  300 / 843 | Loss: 0.1407
# Epoch:  6 / 20 | Train: 97.80% | Validation: 97.67%
# Time elapsed:  1.7182087500890095  min
# Total Training Time: 1.72 min
# Test accuracy 97.04%
# Epoch:  6 / 20 | Batch  400 / 843 | Loss: 0.0392
# Epoch:  6 / 20 | Train: 97.99% | Validation: 97.58%
# Time elapsed:  1.7531673153241476  min
# Total Training Time: 1.75 min
# Test accuracy 97.20%
# Epoch:  6 / 20 | Batch  500 / 843 | Loss: 0.0407
# Epoch:  6 / 20 | Train: 97.66% | Validation: 97.40%
# Time elapsed:  1.7883325854937235  min
# Total Training Time: 1.79 min
# Test accuracy 96.78%
# Epoch:  6 / 20 | Batch  600 / 843 | Loss: 0.0226
# Epoch:  6 / 20 | Train: 97.32% | Validation: 97.03%
# Time elapsed:  1.8242206851641336  min
# Total Training Time: 1.82 min
# Test accuracy 96.56%
# Epoch:  6 / 20 | Batch  700 / 843 | Loss: 0.0618
# Epoch:  6 / 20 | Train: 97.60% | Validation: 97.40%
# Time elapsed:  1.8598995844523112  min
# Total Training Time: 1.86 min
# Test accuracy 96.93%
# Epoch:  6 / 20 | Batch  800 / 843 | Loss: 0.0486
# Epoch:  6 / 20 | Train: 96.95% | Validation: 96.83%
# Time elapsed:  1.8957181175549824  min
# Total Training Time: 1.90 min
# Test accuracy 95.95%
# Epoch:  7 / 20 | Batch  0 / 843 | Loss: 0.9770
# Epoch:  7 / 20 | Train: 97.46% | Validation: 97.15%
# Time elapsed:  1.9295850038528441  min
# Total Training Time: 1.93 min
# Test accuracy 96.64%
# Epoch:  7 / 20 | Batch  100 / 843 | Loss: 0.0522
# Epoch:  7 / 20 | Train: 98.07% | Validation: 97.82%
# Time elapsed:  1.9649051705996194  min
# Total Training Time: 1.96 min
# Test accuracy 97.32%
# Epoch:  7 / 20 | Batch  200 / 843 | Loss: 0.0092
# Epoch:  7 / 20 | Train: 97.87% | Validation: 97.85%
# Time elapsed:  2.000593451658885  min
# Total Training Time: 2.00 min
# Test accuracy 97.13%
# Epoch:  7 / 20 | Batch  300 / 843 | Loss: 0.0523
# Epoch:  7 / 20 | Train: 97.69% | Validation: 97.17%
# Time elapsed:  2.0354844371477765  min
# Total Training Time: 2.04 min
# Test accuracy 96.89%
# Epoch:  7 / 20 | Batch  400 / 843 | Loss: 0.0166
# Epoch:  7 / 20 | Train: 98.24% | Validation: 97.97%
# Time elapsed:  2.071793433030446  min
# Total Training Time: 2.07 min
# Test accuracy 97.24%
# Epoch:  7 / 20 | Batch  500 / 843 | Loss: 0.0916
# Epoch:  7 / 20 | Train: 97.94% | Validation: 97.70%
# Time elapsed:  2.1070526043574014  min
# Total Training Time: 2.11 min
# Test accuracy 96.81%
# Epoch:  7 / 20 | Batch  600 / 843 | Loss: 0.0351
# Epoch:  7 / 20 | Train: 98.28% | Validation: 97.77%
# Time elapsed:  2.142202317714691  min
# Total Training Time: 2.14 min
# Test accuracy 97.42%
# Epoch:  7 / 20 | Batch  700 / 843 | Loss: 0.0442
# Epoch:  7 / 20 | Train: 97.77% | Validation: 97.28%
# Time elapsed:  2.1779571652412413  min
# Total Training Time: 2.18 min
# Test accuracy 96.96%
# Epoch:  7 / 20 | Batch  800 / 843 | Loss: 0.0421
# Epoch:  7 / 20 | Train: 97.44% | Validation: 97.17%
# Time elapsed:  2.213702619075775  min
# Total Training Time: 2.21 min
# Test accuracy 96.43%
# Epoch:  8 / 20 | Batch  0 / 843 | Loss: 0.7513
# Epoch:  8 / 20 | Train: 97.86% | Validation: 97.23%
# Time elapsed:  2.2483731389045714  min
# Total Training Time: 2.25 min
# Test accuracy 96.78%
# Epoch:  8 / 20 | Batch  100 / 843 | Loss: 0.0730
# Epoch:  8 / 20 | Train: 98.03% | Validation: 97.68%
# Time elapsed:  2.2829363385836285  min
# Total Training Time: 2.28 min
# Test accuracy 97.17%
# Epoch:  8 / 20 | Batch  200 / 843 | Loss: 0.0517
# Epoch:  8 / 20 | Train: 97.94% | Validation: 97.63%
# Time elapsed:  2.3186948180198668  min
# Total Training Time: 2.32 min
# Test accuracy 96.94%
# Epoch:  8 / 20 | Batch  300 / 843 | Loss: 0.0299
# Epoch:  8 / 20 | Train: 98.44% | Validation: 98.00%
# Time elapsed:  2.3534666538238525  min
# Total Training Time: 2.35 min
# Test accuracy 97.51%
# Epoch:  8 / 20 | Batch  400 / 843 | Loss: 0.1203
# Epoch:  8 / 20 | Train: 98.24% | Validation: 97.62%
# Time elapsed:  2.38898841937383  min
# Total Training Time: 2.39 min
# Test accuracy 97.40%
# Epoch:  8 / 20 | Batch  500 / 843 | Loss: 0.0252
# Epoch:  8 / 20 | Train: 98.36% | Validation: 97.63%
# Time elapsed:  2.424610936641693  min
# Total Training Time: 2.42 min
# Test accuracy 97.36%
# Epoch:  8 / 20 | Batch  600 / 843 | Loss: 0.1414
# Epoch:  8 / 20 | Train: 97.98% | Validation: 97.50%
# Time elapsed:  2.4605126857757567  min
# Total Training Time: 2.46 min
# Test accuracy 97.02%
# Epoch:  8 / 20 | Batch  700 / 843 | Loss: 0.0148
# Epoch:  8 / 20 | Train: 98.39% | Validation: 97.77%
# Time elapsed:  2.49618976910909  min
# Total Training Time: 2.50 min
# Test accuracy 97.34%
# Epoch:  8 / 20 | Batch  800 / 843 | Loss: 0.0952
# Epoch:  8 / 20 | Train: 98.35% | Validation: 97.83%
# Time elapsed:  2.5319549520810445  min
# Total Training Time: 2.53 min
# Test accuracy 97.51%
# Epoch:  9 / 20 | Batch  0 / 843 | Loss: 0.8875
# Epoch:  9 / 20 | Train: 98.23% | Validation: 97.62%
# Time elapsed:  2.5662726680437724  min
# Total Training Time: 2.57 min
# Test accuracy 97.30%
# Epoch:  9 / 20 | Batch  100 / 843 | Loss: 0.0610
# Epoch:  9 / 20 | Train: 97.84% | Validation: 97.65%
# Time elapsed:  2.6007690032323203  min
# Total Training Time: 2.60 min
# Test accuracy 96.78%
# Epoch:  9 / 20 | Batch  200 / 843 | Loss: 0.0143
# Epoch:  9 / 20 | Train: 98.24% | Validation: 97.77%
# Time elapsed:  2.6369006514549254  min
# Total Training Time: 2.64 min
# Test accuracy 97.19%
# Epoch:  9 / 20 | Batch  300 / 843 | Loss: 0.0341
# Epoch:  9 / 20 | Train: 98.07% | Validation: 97.42%
# Time elapsed:  2.6721356391906737  min
# Total Training Time: 2.67 min
# Test accuracy 97.00%
# Epoch:  9 / 20 | Batch  400 / 843 | Loss: 0.0822
# Epoch:  9 / 20 | Train: 98.53% | Validation: 97.83%
# Time elapsed:  2.707105350494385  min
# Total Training Time: 2.71 min
# Test accuracy 97.42%
# Epoch:  9 / 20 | Batch  500 / 843 | Loss: 0.0201
# Epoch:  9 / 20 | Train: 98.55% | Validation: 97.90%
# Time elapsed:  2.742295968532562  min
# Total Training Time: 2.74 min
# Test accuracy 97.32%
# Epoch:  9 / 20 | Batch  600 / 843 | Loss: 0.0655
# Epoch:  9 / 20 | Train: 98.36% | Validation: 97.77%
# Time elapsed:  2.7773608684539797  min
# Total Training Time: 2.78 min
# Test accuracy 97.21%
# Epoch:  9 / 20 | Batch  700 / 843 | Loss: 0.0526
# Epoch:  9 / 20 | Train: 98.33% | Validation: 97.68%
# Time elapsed:  2.811783719062805  min
# Total Training Time: 2.81 min
# Test accuracy 97.29%
# Epoch:  9 / 20 | Batch  800 / 843 | Loss: 0.1057
# Epoch:  9 / 20 | Train: 98.22% | Validation: 97.33%
# Time elapsed:  2.8471495866775514  min
# Total Training Time: 2.85 min
# Test accuracy 97.28%
# Epoch:  10 / 20 | Batch  0 / 843 | Loss: 0.9955
# Epoch:  10 / 20 | Train: 98.46% | Validation: 97.65%
# Time elapsed:  2.884298316637675  min
# Total Training Time: 2.88 min
# Test accuracy 97.24%
# Epoch:  10 / 20 | Batch  100 / 843 | Loss: 0.0159
# Epoch:  10 / 20 | Train: 98.63% | Validation: 98.10%
# Time elapsed:  2.92063999970754  min
# Total Training Time: 2.92 min
# Test accuracy 97.53%
# Epoch:  10 / 20 | Batch  200 / 843 | Loss: 0.0391
# Epoch:  10 / 20 | Train: 98.55% | Validation: 97.77%
# Time elapsed:  2.9554525017738342  min
# Total Training Time: 2.96 min
# Test accuracy 97.52%
# Epoch:  10 / 20 | Batch  300 / 843 | Loss: 0.0289
# Epoch:  10 / 20 | Train: 98.69% | Validation: 97.95%
# Time elapsed:  2.9910768349965413  min
# Total Training Time: 2.99 min
# Test accuracy 97.56%
# Epoch:  10 / 20 | Batch  400 / 843 | Loss: 0.0377
# Epoch:  10 / 20 | Train: 98.48% | Validation: 97.73%
# Time elapsed:  3.027002453804016  min
# Total Training Time: 3.03 min
# Test accuracy 97.28%
# Epoch:  10 / 20 | Batch  500 / 843 | Loss: 0.0407
# Epoch:  10 / 20 | Train: 98.48% | Validation: 97.85%
# Time elapsed:  3.062668168544769  min
# Total Training Time: 3.06 min
# Test accuracy 97.56%
# Epoch:  10 / 20 | Batch  600 / 843 | Loss: 0.0405
# Epoch:  10 / 20 | Train: 98.44% | Validation: 97.82%
# Time elapsed:  3.0978975693384805  min
# Total Training Time: 3.10 min
# Test accuracy 97.40%
# Epoch:  10 / 20 | Batch  700 / 843 | Loss: 0.0698
# Epoch:  10 / 20 | Train: 98.39% | Validation: 97.58%
# Time elapsed:  3.1331286509831746  min
# Total Training Time: 3.13 min
# Test accuracy 97.27%
# Epoch:  10 / 20 | Batch  800 / 843 | Loss: 0.1023
# Epoch:  10 / 20 | Train: 98.43% | Validation: 97.80%
# Time elapsed:  3.1678758025169373  min
# Total Training Time: 3.17 min
# Test accuracy 97.26%
# Epoch:  11 / 20 | Batch  0 / 843 | Loss: 0.6514
# Epoch:  11 / 20 | Train: 98.12% | Validation: 97.57%
# Time elapsed:  3.201230518023173  min
# Total Training Time: 3.20 min
# Test accuracy 97.48%
# Epoch:  11 / 20 | Batch  100 / 843 | Loss: 0.0187
# Epoch:  11 / 20 | Train: 98.68% | Validation: 97.72%
# Time elapsed:  3.2373234192530314  min
# Total Training Time: 3.24 min
# Test accuracy 97.43%
# Epoch:  11 / 20 | Batch  200 / 843 | Loss: 0.0268
# Epoch:  11 / 20 | Train: 98.53% | Validation: 97.53%
# Time elapsed:  3.2729976693789165  min
# Total Training Time: 3.27 min
# Test accuracy 97.28%
# Epoch:  11 / 20 | Batch  300 / 843 | Loss: 0.0539
# Epoch:  11 / 20 | Train: 98.77% | Validation: 97.95%
# Time elapsed:  3.3079037348429363  min
# Total Training Time: 3.31 min
# Test accuracy 97.49%
# Epoch:  11 / 20 | Batch  400 / 843 | Loss: 0.0270
# Epoch:  11 / 20 | Train: 98.90% | Validation: 98.08%
# Time elapsed:  3.3437655846277874  min
# Total Training Time: 3.34 min
# Test accuracy 97.47%
# Epoch:  11 / 20 | Batch  500 / 843 | Loss: 0.0899
# Epoch:  11 / 20 | Train: 98.33% | Validation: 97.53%
# Time elapsed:  3.3786150018374124  min
# Total Training Time: 3.38 min
# Test accuracy 97.05%
# Epoch:  11 / 20 | Batch  600 / 843 | Loss: 0.0558
# Epoch:  11 / 20 | Train: 98.72% | Validation: 98.03%
# Time elapsed:  3.41449978351593  min
# Total Training Time: 3.41 min
# Test accuracy 97.50%
# Epoch:  11 / 20 | Batch  700 / 843 | Loss: 0.0855
# Epoch:  11 / 20 | Train: 97.59% | Validation: 96.93%
# Time elapsed:  3.449698785940806  min
# Total Training Time: 3.45 min
# Test accuracy 96.41%
# Epoch:  11 / 20 | Batch  800 / 843 | Loss: 0.0482
# Epoch:  11 / 20 | Train: 98.90% | Validation: 97.73%
# Time elapsed:  3.485402437051137  min
# Total Training Time: 3.49 min
# Test accuracy 97.72%
# Epoch:  12 / 20 | Batch  0 / 843 | Loss: 0.8353
# Epoch:  12 / 20 | Train: 98.71% | Validation: 97.68%
# Time elapsed:  3.5189234018325806  min
# Total Training Time: 3.52 min
# Test accuracy 97.69%
# Epoch:  12 / 20 | Batch  100 / 843 | Loss: 0.0234
# Epoch:  12 / 20 | Train: 98.79% | Validation: 97.72%
# Time elapsed:  3.5542691349983215  min
# Total Training Time: 3.55 min
# Test accuracy 97.58%
# Epoch:  12 / 20 | Batch  200 / 843 | Loss: 0.0052
# Epoch:  12 / 20 | Train: 98.76% | Validation: 98.12%
# Time elapsed:  3.589597733815511  min
# Total Training Time: 3.59 min
# Test accuracy 97.63%
# Epoch:  12 / 20 | Batch  300 / 843 | Loss: 0.0169
# Epoch:  12 / 20 | Train: 98.51% | Validation: 97.80%
# Time elapsed:  3.6247879028320313  min
# Total Training Time: 3.62 min
# Test accuracy 97.33%
# Epoch:  12 / 20 | Batch  400 / 843 | Loss: 0.0765
# Epoch:  12 / 20 | Train: 98.69% | Validation: 98.03%
# Time elapsed:  3.659814703464508  min
# Total Training Time: 3.66 min
# Test accuracy 97.37%
# Epoch:  12 / 20 | Batch  500 / 843 | Loss: 0.0100
# Epoch:  12 / 20 | Train: 98.77% | Validation: 97.85%
# Time elapsed:  3.6953437368075055  min
# Total Training Time: 3.70 min
# Test accuracy 97.47%
# Epoch:  12 / 20 | Batch  600 / 843 | Loss: 0.0540
# Epoch:  12 / 20 | Train: 98.68% | Validation: 97.90%
# Time elapsed:  3.7304826855659483  min
# Total Training Time: 3.73 min
# Test accuracy 97.44%
# Epoch:  12 / 20 | Batch  700 / 843 | Loss: 0.0147
# Epoch:  12 / 20 | Train: 99.05% | Validation: 98.12%
# Time elapsed:  3.7658135334650678  min
# Total Training Time: 3.77 min
# Test accuracy 97.89%
# Epoch:  12 / 20 | Batch  800 / 843 | Loss: 0.0598
# Epoch:  12 / 20 | Train: 98.93% | Validation: 98.03%
# Time elapsed:  3.8014695048332214  min
# Total Training Time: 3.80 min
# Test accuracy 97.82%
# Epoch:  13 / 20 | Batch  0 / 843 | Loss: 0.9399
# Epoch:  13 / 20 | Train: 98.65% | Validation: 97.73%
# Time elapsed:  3.835027567545573  min
# Total Training Time: 3.84 min
# Test accuracy 97.49%
# Epoch:  13 / 20 | Batch  100 / 843 | Loss: 0.0128
# Epoch:  13 / 20 | Train: 99.03% | Validation: 97.75%
# Time elapsed:  3.8709339340527853  min
# Total Training Time: 3.87 min
# Test accuracy 97.67%
# Epoch:  13 / 20 | Batch  200 / 843 | Loss: 0.0381
# Epoch:  13 / 20 | Train: 98.89% | Validation: 98.00%
# Time elapsed:  3.906052633126577  min
# Total Training Time: 3.91 min
# Test accuracy 97.59%
# Epoch:  13 / 20 | Batch  300 / 843 | Loss: 0.0692
# Epoch:  13 / 20 | Train: 98.73% | Validation: 97.88%
# Time elapsed:  3.9413059035936993  min
# Total Training Time: 3.94 min
# Test accuracy 97.51%
# Epoch:  13 / 20 | Batch  400 / 843 | Loss: 0.0094
# Epoch:  13 / 20 | Train: 98.54% | Validation: 97.68%
# Time elapsed:  3.9773079832394918  min
# Total Training Time: 3.98 min
# Test accuracy 97.23%
# Epoch:  13 / 20 | Batch  500 / 843 | Loss: 0.0410
# Epoch:  13 / 20 | Train: 98.67% | Validation: 97.40%
# Time elapsed:  4.012329936027527  min
# Total Training Time: 4.01 min
# Test accuracy 97.41%
# Epoch:  13 / 20 | Batch  600 / 843 | Loss: 0.0163
# Epoch:  13 / 20 | Train: 98.81% | Validation: 97.77%
# Time elapsed:  4.047671699523926  min
# Total Training Time: 4.05 min
# Test accuracy 97.55%
# Epoch:  13 / 20 | Batch  700 / 843 | Loss: 0.0471
# Epoch:  13 / 20 | Train: 98.96% | Validation: 97.75%
# Time elapsed:  4.082720216115316  min
# Total Training Time: 4.08 min
# Test accuracy 97.79%
# Epoch:  13 / 20 | Batch  800 / 843 | Loss: 0.0224
# Epoch:  13 / 20 | Train: 99.08% | Validation: 98.30%
# Time elapsed:  4.118446187178294  min
# Total Training Time: 4.12 min
# Test accuracy 98.00%
# Epoch:  14 / 20 | Batch  0 / 843 | Loss: 1.1161
# Epoch:  14 / 20 | Train: 98.77% | Validation: 98.10%
# Time elapsed:  4.151877586046854  min
# Total Training Time: 4.15 min
# Test accuracy 97.28%
# Epoch:  14 / 20 | Batch  100 / 843 | Loss: 0.0433
# Epoch:  14 / 20 | Train: 99.00% | Validation: 97.85%
# Time elapsed:  4.18739550113678  min
# Total Training Time: 4.19 min
# Test accuracy 97.63%
# Epoch:  14 / 20 | Batch  200 / 843 | Loss: 0.0141
# Epoch:  14 / 20 | Train: 99.15% | Validation: 98.08%
# Time elapsed:  4.221541301409403  min
# Total Training Time: 4.22 min
# Test accuracy 98.00%
# Epoch:  14 / 20 | Batch  300 / 843 | Loss: 0.0477
# Epoch:  14 / 20 | Train: 98.80% | Validation: 97.87%
# Time elapsed:  4.256996917724609  min
# Total Training Time: 4.26 min
# Test accuracy 97.49%
# Epoch:  14 / 20 | Batch  400 / 843 | Loss: 0.0620
# Epoch:  14 / 20 | Train: 99.15% | Validation: 98.15%
# Time elapsed:  4.29284671942393  min
# Total Training Time: 4.29 min
# Test accuracy 97.86%
# Epoch:  14 / 20 | Batch  500 / 843 | Loss: 0.0848
# Epoch:  14 / 20 | Train: 98.78% | Validation: 97.85%
# Time elapsed:  4.3284933487574255  min
# Total Training Time: 4.33 min
# Test accuracy 97.38%
# Epoch:  14 / 20 | Batch  600 / 843 | Loss: 0.0061
# Epoch:  14 / 20 | Train: 98.93% | Validation: 98.12%
# Time elapsed:  4.364512685934702  min
# Total Training Time: 4.36 min
# Test accuracy 97.67%
# Epoch:  14 / 20 | Batch  700 / 843 | Loss: 0.0210
# Epoch:  14 / 20 | Train: 98.90% | Validation: 97.98%
# Time elapsed:  4.399851834774017  min
# Total Training Time: 4.40 min
# Test accuracy 97.65%
# Epoch:  14 / 20 | Batch  800 / 843 | Loss: 0.0463
# Epoch:  14 / 20 | Train: 98.76% | Validation: 98.25%
# Time elapsed:  4.434151117006937  min
# Total Training Time: 4.43 min
# Test accuracy 97.53%
# Epoch:  15 / 20 | Batch  0 / 843 | Loss: 0.7898
# Epoch:  15 / 20 | Train: 98.84% | Validation: 97.97%
# Time elapsed:  4.468997486432394  min
# Total Training Time: 4.47 min
# Test accuracy 97.44%
# Epoch:  15 / 20 | Batch  100 / 843 | Loss: 0.0254
# Epoch:  15 / 20 | Train: 99.09% | Validation: 98.07%
# Time elapsed:  4.504997150103251  min
# Total Training Time: 4.50 min
# Test accuracy 97.79%
# Epoch:  15 / 20 | Batch  200 / 843 | Loss: 0.0021
# Epoch:  15 / 20 | Train: 98.95% | Validation: 97.83%
# Time elapsed:  4.54026171763738  min
# Total Training Time: 4.54 min
# Test accuracy 97.80%
# Epoch:  15 / 20 | Batch  300 / 843 | Loss: 0.0407
# Epoch:  15 / 20 | Train: 98.92% | Validation: 97.97%
# Time elapsed:  4.576668151219686  min
# Total Training Time: 4.58 min
# Test accuracy 97.60%
# Epoch:  15 / 20 | Batch  400 / 843 | Loss: 0.0942
# Epoch:  15 / 20 | Train: 98.83% | Validation: 97.98%
# Time elapsed:  4.611838718255361  min
# Total Training Time: 4.61 min
# Test accuracy 97.40%
# Epoch:  15 / 20 | Batch  500 / 843 | Loss: 0.0276
# Epoch:  15 / 20 | Train: 99.08% | Validation: 98.10%
# Time elapsed:  4.648015936215718  min
# Total Training Time: 4.65 min
# Test accuracy 97.74%
# Epoch:  15 / 20 | Batch  600 / 843 | Loss: 0.0151
# Epoch:  15 / 20 | Train: 98.43% | Validation: 97.53%
# Time elapsed:  4.683321686585744  min
# Total Training Time: 4.68 min
# Test accuracy 97.16%
# Epoch:  15 / 20 | Batch  700 / 843 | Loss: 0.0778
# Epoch:  15 / 20 | Train: 99.21% | Validation: 98.18%
# Time elapsed:  4.718873703479767  min
# Total Training Time: 4.72 min
# Test accuracy 97.67%
# Epoch:  15 / 20 | Batch  800 / 843 | Loss: 0.0038
# Epoch:  15 / 20 | Train: 98.84% | Validation: 97.87%
# Time elapsed:  4.7537460009257  min
# Total Training Time: 4.75 min
# Test accuracy 97.62%
# Epoch:  16 / 20 | Batch  0 / 843 | Loss: 0.9540
# Epoch:  16 / 20 | Train: 98.65% | Validation: 97.80%
# Time elapsed:  4.787920852502187  min
# Total Training Time: 4.79 min
# Test accuracy 97.41%
# Epoch:  16 / 20 | Batch  100 / 843 | Loss: 0.0092
# Epoch:  16 / 20 | Train: 99.27% | Validation: 98.37%
# Time elapsed:  4.8233898997306826  min
# Total Training Time: 4.82 min
# Test accuracy 97.93%
# Epoch:  16 / 20 | Batch  200 / 843 | Loss: 0.0332
# Epoch:  16 / 20 | Train: 99.28% | Validation: 98.05%
# Time elapsed:  4.858630518118541  min
# Total Training Time: 4.86 min
# Test accuracy 97.79%
# Epoch:  16 / 20 | Batch  300 / 843 | Loss: 0.0159
# Epoch:  16 / 20 | Train: 99.07% | Validation: 98.07%
# Time elapsed:  4.894398021697998  min
# Total Training Time: 4.89 min
# Test accuracy 97.73%
# Epoch:  16 / 20 | Batch  400 / 843 | Loss: 0.0588
# Epoch:  16 / 20 | Train: 98.96% | Validation: 97.77%
# Time elapsed:  4.9296738346417746  min
# Total Training Time: 4.93 min
# Test accuracy 97.51%
# Epoch:  16 / 20 | Batch  500 / 843 | Loss: 0.0203
# Epoch:  16 / 20 | Train: 99.28% | Validation: 98.15%
# Time elapsed:  4.964083619912466  min
# Total Training Time: 4.96 min
# Test accuracy 97.90%
# Epoch:  16 / 20 | Batch  600 / 843 | Loss: 0.0778
# Epoch:  16 / 20 | Train: 99.42% | Validation: 98.33%
# Time elapsed:  4.999678285916646  min
# Total Training Time: 5.00 min
# Test accuracy 98.02%
# Epoch:  16 / 20 | Batch  700 / 843 | Loss: 0.0805
# Epoch:  16 / 20 | Train: 99.11% | Validation: 97.93%
# Time elapsed:  5.034321717421213  min
# Total Training Time: 5.03 min
# Test accuracy 97.75%
# Epoch:  16 / 20 | Batch  800 / 843 | Loss: 0.0213
# Epoch:  16 / 20 | Train: 99.33% | Validation: 98.12%
# Time elapsed:  5.069414933522542  min
# Total Training Time: 5.07 min
# Test accuracy 97.89%
# Epoch:  17 / 20 | Batch  0 / 843 | Loss: 0.9065
# Epoch:  17 / 20 | Train: 99.44% | Validation: 98.18%
# Time elapsed:  5.102968935171763  min
# Total Training Time: 5.10 min
# Test accuracy 97.90%
# Epoch:  17 / 20 | Batch  100 / 843 | Loss: 0.0102
# Epoch:  17 / 20 | Train: 99.07% | Validation: 97.85%
# Time elapsed:  5.138289300600688  min
# Total Training Time: 5.14 min
# Test accuracy 97.60%
# Epoch:  17 / 20 | Batch  200 / 843 | Loss: 0.0575
# Epoch:  17 / 20 | Train: 99.41% | Validation: 98.28%
# Time elapsed:  5.173746685187022  min
# Total Training Time: 5.17 min
# Test accuracy 98.00%
# Epoch:  17 / 20 | Batch  300 / 843 | Loss: 0.0082
# Epoch:  17 / 20 | Train: 99.27% | Validation: 97.98%
# Time elapsed:  5.2083375175793964  min
# Total Training Time: 5.21 min
# Test accuracy 97.81%
# Epoch:  17 / 20 | Batch  400 / 843 | Loss: 0.0522
# Epoch:  17 / 20 | Train: 99.27% | Validation: 98.03%
# Time elapsed:  5.244426953792572  min
# Total Training Time: 5.24 min
# Test accuracy 97.79%
# Epoch:  17 / 20 | Batch  500 / 843 | Loss: 0.0020
# Epoch:  17 / 20 | Train: 99.30% | Validation: 98.20%
# Time elapsed:  5.282645285129547  min
# Total Training Time: 5.28 min
# Test accuracy 97.89%
# Epoch:  17 / 20 | Batch  600 / 843 | Loss: 0.0108
# Epoch:  17 / 20 | Train: 99.30% | Validation: 98.30%
# Time elapsed:  5.3226850191752115  min
# Total Training Time: 5.32 min
# Test accuracy 97.66%
# Epoch:  17 / 20 | Batch  700 / 843 | Loss: 0.0166
# Epoch:  17 / 20 | Train: 99.01% | Validation: 98.07%
# Time elapsed:  5.358868499596913  min
# Total Training Time: 5.36 min
# Test accuracy 97.62%
# Epoch:  17 / 20 | Batch  800 / 843 | Loss: 0.0168
# Epoch:  17 / 20 | Train: 99.32% | Validation: 98.13%
# Time elapsed:  5.394592086474101  min
# Total Training Time: 5.39 min
# Test accuracy 97.79%
# Epoch:  18 / 20 | Batch  0 / 843 | Loss: 0.7384
# Epoch:  18 / 20 | Train: 99.03% | Validation: 97.73%
# Time elapsed:  5.429599849383036  min
# Total Training Time: 5.43 min
# Test accuracy 97.66%
# Epoch:  18 / 20 | Batch  100 / 843 | Loss: 0.0122
# Epoch:  18 / 20 | Train: 99.42% | Validation: 98.13%
# Time elapsed:  5.465567998091379  min
# Total Training Time: 5.47 min
# Test accuracy 97.83%
# Epoch:  18 / 20 | Batch  200 / 843 | Loss: 0.0052
# Epoch:  18 / 20 | Train: 98.78% | Validation: 97.70%
# Time elapsed:  5.501015281677246  min
# Total Training Time: 5.50 min
# Test accuracy 97.45%
# Epoch:  18 / 20 | Batch  300 / 843 | Loss: 0.0556
# Epoch:  18 / 20 | Train: 98.90% | Validation: 97.98%
# Time elapsed:  5.535668369134267  min
# Total Training Time: 5.54 min
# Test accuracy 97.49%
# Epoch:  18 / 20 | Batch  400 / 843 | Loss: 0.0524
# Epoch:  18 / 20 | Train: 99.19% | Validation: 97.90%
# Time elapsed:  5.570994734764099  min
# Total Training Time: 5.57 min
# Test accuracy 97.75%
# Epoch:  18 / 20 | Batch  500 / 843 | Loss: 0.0411
# Epoch:  18 / 20 | Train: 99.43% | Validation: 98.22%
# Time elapsed:  5.605542202790578  min
# Total Training Time: 5.61 min
# Test accuracy 97.92%
# Epoch:  18 / 20 | Batch  600 / 843 | Loss: 0.0212
# Epoch:  18 / 20 | Train: 99.15% | Validation: 98.05%
# Time elapsed:  5.642029503981273  min
# Total Training Time: 5.64 min
# Test accuracy 97.68%
# Epoch:  18 / 20 | Batch  700 / 843 | Loss: 0.0076
# Epoch:  18 / 20 | Train: 99.37% | Validation: 98.37%
# Time elapsed:  5.67695783774058  min
# Total Training Time: 5.68 min
# Test accuracy 98.00%
# Epoch:  18 / 20 | Batch  800 / 843 | Loss: 0.0111
# Epoch:  18 / 20 | Train: 99.41% | Validation: 98.13%
# Time elapsed:  5.712420753637949  min
# Total Training Time: 5.71 min
# Test accuracy 97.98%
# Epoch:  19 / 20 | Batch  0 / 843 | Loss: 1.1310
# Epoch:  19 / 20 | Train: 99.22% | Validation: 98.10%
# Time elapsed:  5.7461754043896995  min
# Total Training Time: 5.75 min
# Test accuracy 97.68%
# Epoch:  19 / 20 | Batch  100 / 843 | Loss: 0.0068
# Epoch:  19 / 20 | Train: 99.53% | Validation: 98.38%
# Time elapsed:  5.782671618461609  min
# Total Training Time: 5.78 min
# Test accuracy 98.00%
# Epoch:  19 / 20 | Batch  200 / 843 | Loss: 0.0089
# Epoch:  19 / 20 | Train: 99.38% | Validation: 97.92%
# Time elapsed:  5.818027818202973  min
# Total Training Time: 5.82 min
# Test accuracy 97.82%
# Epoch:  19 / 20 | Batch  300 / 843 | Loss: 0.0395
# Epoch:  19 / 20 | Train: 99.07% | Validation: 97.83%
# Time elapsed:  5.855884353319804  min
# Total Training Time: 5.86 min
# Test accuracy 97.62%
# Epoch:  19 / 20 | Batch  400 / 843 | Loss: 0.0129
# Epoch:  19 / 20 | Train: 99.39% | Validation: 98.17%
# Time elapsed:  5.892624616622925  min
# Total Training Time: 5.89 min
# Test accuracy 97.85%
# Epoch:  19 / 20 | Batch  500 / 843 | Loss: 0.0398
# Epoch:  19 / 20 | Train: 99.42% | Validation: 98.07%
# Time elapsed:  5.929544234275818  min
# Total Training Time: 5.93 min
# Test accuracy 97.81%
# Epoch:  19 / 20 | Batch  600 / 843 | Loss: 0.0030
# Epoch:  19 / 20 | Train: 99.48% | Validation: 98.15%
# Time elapsed:  5.965630221366882  min
# Total Training Time: 5.97 min
# Test accuracy 98.17%
# Epoch:  19 / 20 | Batch  700 / 843 | Loss: 0.0425
# Epoch:  19 / 20 | Train: 99.38% | Validation: 98.35%
# Time elapsed:  6.000758635997772  min
# Total Training Time: 6.00 min
# Test accuracy 98.03%
# Epoch:  19 / 20 | Batch  800 / 843 | Loss: 0.1268
# Epoch:  19 / 20 | Train: 98.96% | Validation: 97.75%
# Time elapsed:  6.035831133524577  min
# Total Training Time: 6.04 min
# Test accuracy 97.28%
# Epoch:  20 / 20 | Batch  0 / 843 | Loss: 1.1433
# Epoch:  20 / 20 | Train: 99.47% | Validation: 98.17%
# Time elapsed:  6.069272335370382  min
# Total Training Time: 6.07 min
# Test accuracy 97.82%
# Epoch:  20 / 20 | Batch  100 / 843 | Loss: 0.0064
# Epoch:  20 / 20 | Train: 99.52% | Validation: 98.20%
# Time elapsed:  6.10518026749293  min
# Total Training Time: 6.11 min
# Test accuracy 97.95%
# Epoch:  20 / 20 | Batch  200 / 843 | Loss: 0.0321
# Epoch:  20 / 20 | Train: 99.53% | Validation: 98.33%
# Time elapsed:  6.140378288427988  min
# Total Training Time: 6.14 min
# Test accuracy 97.93%
# Epoch:  20 / 20 | Batch  300 / 843 | Loss: 0.0041
# Epoch:  20 / 20 | Train: 99.49% | Validation: 98.00%
# Time elapsed:  6.175669936339061  min
# Total Training Time: 6.18 min
# Test accuracy 97.85%
# Epoch:  20 / 20 | Batch  400 / 843 | Loss: 0.0154
# Epoch:  20 / 20 | Train: 99.51% | Validation: 98.20%
# Time elapsed:  6.212491651376088  min
# Total Training Time: 6.21 min
# Test accuracy 97.95%
# Epoch:  20 / 20 | Batch  500 / 843 | Loss: 0.0055
# Epoch:  20 / 20 | Train: 99.48% | Validation: 98.12%
# Time elapsed:  6.247501452763875  min
# Total Training Time: 6.25 min
# Test accuracy 97.75%
# Epoch:  20 / 20 | Batch  600 / 843 | Loss: 0.0018
# Epoch:  20 / 20 | Train: 99.26% | Validation: 98.15%
# Time elapsed:  6.283039287726084  min
# Total Training Time: 6.28 min
# Test accuracy 97.91%
# Epoch:  20 / 20 | Batch  700 / 843 | Loss: 0.0176
# Epoch:  20 / 20 | Train: 99.28% | Validation: 98.00%
# Time elapsed:  6.317737317085266  min
# Total Training Time: 6.32 min
# Test accuracy 97.72%
# Epoch:  20 / 20 | Batch  800 / 843 | Loss: 0.0039
# Epoch:  20 / 20 | Train: 99.40% | Validation: 98.08%
# Time elapsed:  6.353575452168783  min
# Total Training Time: 6.35 min
# Test accuracy 97.77%

# %%
import matplotlib.pyplot as plt
plt.plot(range(len(minibatch_loss_list)), minibatch_loss_list)
plt.xlabel('Iterations')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
import numpy as np
num_epochs = len(train_acc_list)
plt.plot(np.arange(1, num_epochs+1),
        train_acc_list, label='Training')
plt.plot(np.arange(1, num_epochs+1),
        valid_acc_list, label='Validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
